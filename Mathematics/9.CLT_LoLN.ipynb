# %% [markdown]
# # Домашнее задание по теме "Центральная Предельная Теорема и Закон Больших Чисел"

# %% [markdown]
# ## Задание.
# В этом задании нужно убедиться, что ЦПТ действительно работает.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts

# %% [markdown]
# Создайте случайную величину из любого выбранного вами распределения, для разных значений n сгенерируйте 1000 выборок размера n и постройте гистрограммы средних этих выборок.

# %% [markdown]
# # Проверка ЦПТ для нормального распределения

# %%
# здесь массив распределений
rv = sts.norm
sample = rv.rvs(size=1000)

# %%
x = np.linspace(0,3,100)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=30, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
# Параметры запуска: размеры выборок и количество повторов генерации
n1 = 2

samples_count = 1000
# Массивы для сохранения средних по выборкам
a1 = np.array([])

for number in range(samples_count):
    # На каждом цикле генерируем выборки разных размеров
    sample1 = rv.rvs(size=n1)
    # Считаем среднее по каждой выборке и добавляем в массив средних
    a1 = np.append(a1, sample1.mean())

# %%
# Строим графики
# Подписи для графиков
label_1 = 'sample of ' + str(n1) + ' histogram'
plt.hist(a1, density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Параметры запуска: размеры выборок и количество повторов генерации
n2 = 10

samples_count = 1000
# Массивы для сохранения средних по выборкам
a2 = np.array([])

for number in range(samples_count):
    # На каждом цикле генерируем выборки разных размеров
    sample2 = rv.rvs(size=n2)
    # Считаем среднее по каждой выборке и добавляем в массив средних
    a2 = np.append(a2, sample2.mean())

# %%
# Строим графики
# Подписи для графиков
label_2 = 'sample of ' + str(n2) + ' histogram'
plt.hist(a2, density=True, label=label_2)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Параметры запуска: размеры выборок и количество повторов генерации
n3 = 40

samples_count = 1000
# Массивы для сохранения средних по выборкам
a3 = np.array([])

for number in range(samples_count):
    # На каждом цикле генерируем выборки разных размеров
    sample3 = rv.rvs(size=n3)
    # Считаем среднее по каждой выборке и добавляем в массив средних
    a3 = np.append(a3, sample3.mean())

# %%
# Строим графики
# Подписи для графиков
label_3 = 'sample of ' + str(n3) + ' histogram'
plt.hist(a3, density=True, label=label_3)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %% [markdown]
# # Проверка ЦПТ для экспоненциального распределения

# %%
# здесь массив распределений
rv2 = sts.expon
sample = rv2.rvs(size=1000)

# %%
x = np.linspace(0,3,100)
pdf = rv2.pdf(x)
plt.hist(sample, density=True, bins=30, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
# Параметры запуска: размеры выборок и количество повторов генерации
n1 = 2

samples_count = 1000
# Массивы для сохранения средних по выборкам
a1 = np.array([])

for number in range(samples_count):
    # На каждом цикле генерируем выборки разных размеров
    sample1 = rv2.rvs(size=n1)
    # Считаем среднее по каждой выборке и добавляем в массив средних
    a1 = np.append(a1, sample1.mean())

# %%
# Строим графики
# Подписи для графиков
label_1 = 'sample of ' + str(n1) + ' histogram'
plt.hist(a1, density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Параметры запуска: размеры выборок и количество повторов генерации
n2 = 10

samples_count = 1000
# Массивы для сохранения средних по выборкам
a2 = np.array([])

for number in range(samples_count):
    # На каждом цикле генерируем выборки разных размеров
    sample2 = rv2.rvs(size=n2)
    # Считаем среднее по каждой выборке и добавляем в массив средних
    a2 = np.append(a2, sample2.mean())

# %%
# Строим графики
# Подписи для графиков
label_2 = 'sample of ' + str(n2) + ' histogram'
plt.hist(a2, density=True, label=label_2)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Параметры запуска: размеры выборок и количество повторов генерации
n3 = 200

samples_count = 1000
# Массивы для сохранения средних по выборкам
a3 = np.array([])

for number in range(samples_count):
    # На каждом цикле генерируем выборки разных размеров
    sample3 = rv2.rvs(size=n3)
    # Считаем среднее по каждой выборке и добавляем в массив средних
    a3 = np.append(a3, sample3.mean())

# %%
# Строим графики
# Подписи для графиков
label_3 = 'sample of ' + str(n3) + ' histogram'
plt.hist(a3, density=True, label=label_3)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %% [markdown]
# ### Вывод
# Для нормального распределения ЦПТ работает и уже при n = 40, уже видим классическое нормальное распределение, что означает, что средние значения выборок действительно стремятся к мат ожиданию нормального распределения случайной величины.
# Для экспоненциального распределения ЦПТ так же работает, правда наблюдается это при бОльшем значении n = 200
