# %% [markdown]
# # Лекция - практика по Управляющим конструкциям и коллекциям. Часть 2.

# %% [markdown]
# ### Задача 1

# %%
dict_1 = {1: 2}
dict_2 = {3: 4}
dict_1.update(dict_2)
sorted(dict_1.values())
print(dict_1)
my_dict = {    'id1': 654321,     'id2': 123456,     'id3': 777777}
sorted(my_dict.values())
print(my_dict)
# Out:
# {1: 2, 3: 4}
# {'id1': 654321, 'id2': 123456, 'id3': 777777}

# %% [markdown]
# ### Задача 2

# %%
bodycount = {  
    'Проклятие Черной жемчужины': 
    { 
        'человек': 17 
    },    
    'Сундук мертвеца':
    {
        'человек': 56,  
        'раков-отшельников': 1 
    },   
    'На краю света':
    {
        'человек': 88  
    },   
    'На странных берегах': 
    {  
        'человек': 56,  
        'русалок': 2,  
        'ядовитых жаб': 3,       
        'пиратов зомби': 2 
    }
}


all_dead = 0
for dead in bodycount.values():
    all_dead += sum(dead.values())

print(all_dead)
# Out:
# 225

# %% [markdown]
# ### Задача 3

# %%
some_oxy_text = '''Весь мой рэп, если коротко, про то, что
Уж который год который город под подошвой
В гору, когда прет. Потом под гору, когда тошно
Я не то, что Гулливер, но все же город под подошвой
Город под подошвой, город под подошвой
Светофоры, госпошлины, сборы и таможни
Я не знаю, вброд или на дно эта дорожка
Ты живешь под каблуком, у меня - город под подошвой'''
list_text = list(some_oxy_text)
print(list_text)
words = list(some_oxy_text.split( ))
for num in words:
    a = list_text.count(words[num]) 
    repeating.setdefault(words[num], a)
print(repeating)
# Out:
# ['В', 'е', 'с', 'ь', ' ', 'м', 'о', 'й', ' ', 'р', 'э', 'п', ',', ' ', 'е', 'с', 'л', 'и', ' ', 'к', 'о', 'р', 'о', 'т', 'к', 'о', ',', ' ', 'п', 'р', 'о', ' ', 'т', 'о', ',', ' ', 'ч', 'т', 'о', '\n', 'У', 'ж', ' ', 'к', 'о', 'т', 'о', 'р', 'ы', 'й', ' ', 'г', 'о', 'д', ' ', 'к', 'о', 'т', 'о', 'р', 'ы', 'й', ' ', 'г', 'о', 'р', 'о', 'д', ' ', 'п', 'о', 'д', ' ', 'п', 'о', 'д', 'о', 'ш', 'в', 'о', 'й', '\n', 'В', ' ', 'г', 'о', 'р', 'у', ',', ' ', 'к', 'о', 'г', 'д', 'а', ' ', 'п', 'р', 'е', 'т', '.', ' ', 'П', 'о', 'т', 'о', 'м', ' ', 'п', 'о', 'д', ' ', 'г', 'о', 'р', 'у', ',', ' ', 'к', 'о', 'г', 'д', 'а', ' ', 'т', 'о', 'ш', 'н', 'о', '\n', 'Я', ' ', 'н', 'е', ' ', 'т', 'о', ',', ' ', 'ч', 'т', 'о', ' ', 'Г', 'у', 'л', 'л', 'и', 'в', 'е', 'р', ',', ' ', 'н', 'о', ' ', 'в', 'с', 'е', ' ', 'ж', 'е', ' ', 'г', 'о', 'р', 'о', 'д', ' ', 'п', 'о', 'д', ' ', 'п', 'о', 'д', 'о', 'ш', 'в', 'о', 'й', '\n', 'Г', 'о', 'р', 'о', 'д', ' ', 'п', 'о', 'д', ' ', 'п', 'о', 'д', 'о', 'ш', 'в', 'о', 'й', ',', ' ', 'г', 'о', 'р', 'о', 'д', ' ', 'п', 'о', 'д', ' ', 'п', 'о', 'д', 'о', 'ш', 'в', 'о', 'й', '\n', 'С', 'в', 'е', 'т', 'о', 'ф', 'о', 'р', 'ы', ',', ' ', 'г', 'о', 'с', 'п', 'о', 'ш', 'л', 'и', 'н', 'ы', ',', ' ', 'с', 'б', 'о', 'р', 'ы', ' ', 'и', ' ', 'т', 'а', 'м', 'о', 'ж', 'н', 'и', '\n', 'Я', ' ', 'н', 'е', ' ', 'з', 'н', 'а', 'ю', ',', ' ', 'в', 'б', 'р', 'о', 'д', ' ', 'и', 'л', 'и', ' ', 'н', 'а', ' ', 'д', 'н', 'о', ' ', 'э', 'т', 'а', ' ', 'д', 'о', 'р', 'о', 'ж', 'к', 'а', '\n', 'Т', 'ы', ' ', 'ж', 'и', 'в', 'е', 'ш', 'ь', ' ', 'п', 'о', 'д', ' ', 'к', 'а', 'б', 'л', 'у', 'к', 'о', 'м', ',', ' ', 'у', ' ', 'м', 'е', 'н', 'я', ' ', '-', ' ', 'г', 'о', 'р', 'о', 'д', ' ', 'п', 'о', 'д', ' ', 'п', 'о', 'д', 'о', 'ш', 'в', 'о', 'й']
